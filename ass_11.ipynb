# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagvatibhatu90/UCS420/blob/main/ass_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ques 1. Design a Cognitive Assistant for Reading Labels of medicine bottle

# %% [markdown]
# ![x.PNG](data:image/png;base64,...)

# %% [markdown]
# ![x1.PNG](data:image/png;base64,...)

# %% [markdown]
# # Ques 2.Design an Emotion-aware Cognitive Assistant using Facial Expression Detection

# %% [markdown]
# ![ass11-2-3.jpg](data:image/jpeg;base64,...)![ass11-2-2.jpg](data:image/jpeg;base64,...)![ass11-2-4 (1).jpg](data:image/jpeg;base64,...)![ass11-2-1.jpg](data:image/jpeg;base64,...)
